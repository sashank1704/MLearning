# %% [markdown]
# <a href="https://colab.research.google.com/github/sashank1704/MLearning/blob/main/irisclassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0e1d85e9-9eb3-4944-aeab-5826afe872a4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0e1d85e9-9eb3-4944-aeab-5826afe872a4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
iris = pd.read_csv(io.BytesIO(uploaded['iris.csv']))

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length   petal_width           class
# 0             5.1          3.5           1.4           0.2     iris_setosa
# 1             4.9          3.0           1.4           0.2     iris_setosa
# 2             4.7          3.2           1.3           0.2     iris_setosa
# 3             4.6          3.1           1.5           0.2     iris_setosa
# 4             5.0          3.6           1.4           0.2     iris_setosa
# ..            ...          ...           ...           ...             ...
# 145           6.7          3.0           5.2           2.3  iris_virginica
# 146           6.3          2.5           5.0           1.9  iris_virginica
# 147           6.5          3.0           5.2           2.0  iris_virginica
# 148           6.2          3.4           5.4           2.3  iris_virginica
# 149           5.9          3.0           5.1           1.8  iris_virginica
#
# [150 rows x 5 columns]

# %%
print(iris.shape)
# Out:
# (150, 5)

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length   petal_width
# count    150.000000   150.000000    150.000000    150.000000
# mean       5.843333     3.054000      3.758667      1.198667
# std        0.828066     0.433594      1.764420      0.763161
# min        4.300000     2.000000      1.000000      0.100000
# 25%        5.100000     2.800000      1.600000      0.300000
# 50%        5.800000     3.000000      4.350000      1.300000
# 75%        6.400000     3.300000      5.100000      1.800000
# max        7.900000     4.400000      6.900000      2.500000

# %%
x=iris.drop(columns=['class'])
x
# Out:
#      sepal_length  sepal_width  petal_length   petal_width
# 0             5.1          3.5           1.4           0.2
# 1             4.9          3.0           1.4           0.2
# 2             4.7          3.2           1.3           0.2
# 3             4.6          3.1           1.5           0.2
# 4             5.0          3.6           1.4           0.2
# ..            ...          ...           ...           ...
# 145           6.7          3.0           5.2           2.3
# 146           6.3          2.5           5.0           1.9
# 147           6.5          3.0           5.2           2.0
# 148           6.2          3.4           5.4           2.3
# 149           5.9          3.0           5.1           1.8
#
# [150 rows x 4 columns]

# %%
print(x.shape)
# Out:
# (150, 4)

# %%
y=iris['class']
y
# Out:
# 0         iris_setosa
# 1         iris_setosa
# 2         iris_setosa
# 3         iris_setosa
# 4         iris_setosa
#             ...
# 145    iris_virginica
# 146    iris_virginica
# 147    iris_virginica
# 148    iris_virginica
# 149    iris_virginica
# Name: class, Length: 150, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.4)

# %%
x_train
# Out:
#      sepal_length  sepal_width  petal_length   petal_width
# 7             5.0          3.4           1.5           0.2
# 5             5.4          3.9           1.7           0.4
# 102           7.1          3.0           5.9           2.1
# 148           6.2          3.4           5.4           2.3
# 143           6.8          3.2           5.9           2.3
# ..            ...          ...           ...           ...
# 116           6.5          3.0           5.5           1.8
# 132           6.4          2.8           5.6           2.2
# 62            6.0          2.2           4.0           1.0
# 43            5.0          3.5           1.6           0.6
# 129           7.2          3.0           5.8           1.6
#
# [90 rows x 4 columns]

# %%
y_train
# Out:
# 7          iris_setosa
# 5          iris_setosa
# 102     iris_virginica
# 148     iris_virginica
# 143     iris_virginica
#             ...
# 116     iris_virginica
# 132     iris_virginica
# 62     iris_versicolor
# 43         iris_setosa
# 129     iris_virginica
# Name: class, Length: 90, dtype: object

# %%
x_test
# Out:
#      sepal_length  sepal_width  petal_length   petal_width
# 8             4.4          2.9           1.4           0.2
# 87            6.3          2.3           4.4           1.3
# 61            5.9          3.0           4.2           1.5
# 131           7.9          3.8           6.4           2.0
# 71            6.1          2.8           4.0           1.3
# 10            5.4          3.7           1.5           0.2
# 133           6.3          2.8           5.1           1.5
# 1             4.9          3.0           1.4           0.2
# 76            6.8          2.8           4.8           1.4
# 55            5.7          2.8           4.5           1.3
# 73            6.1          2.8           4.7           1.2
# 15            5.7          4.4           1.5           0.4
# 57            4.9          2.4           3.3           1.0
# 128           6.4          2.8           5.6           2.1
# 110           6.5          3.2           5.1           2.0
# ...

# %%
y_test
# Out:
# 8          iris_setosa
# 87     iris_versicolor
# 61     iris_versicolor
# 131     iris_virginica
# 71     iris_versicolor
# 10         iris_setosa
# 133     iris_virginica
# 1          iris_setosa
# 76     iris_versicolor
# 55     iris_versicolor
# 73     iris_versicolor
# 15         iris_setosa
# 57     iris_versicolor
# 128     iris_virginica
# 110     iris_virginica
# 13         iris_setosa
# 115     iris_virginica
# 28         iris_setosa
# 16         iris_setosa
# 141     iris_virginica
# 136     iris_virginica
# 113     iris_virginica
# 93     iris_versicolor
# 38         iris_setosa
# 20         iris_setosa
# 91     iris_versicolor
# 118     iris_virginica
# 75     iris_versicolor
# 14         iris_setosa
# 149     iris_virginica
# 0          iris_setosa
# 23         iris_setosa
# 50     iris_versicolor
# 60     iris_versicolor
# 17         iris_setosa
# 114     iris_virginica
# 88     iris_versicolor
# 145     iris_virginica
# 121     iris_virginica
# 117     iris_virginica
# ...

# %%
from sklearn import neighbors
classifier1=neighbors.KNeighborsClassifier()

# %%
classifier1.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
predictions=classifier1.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,predictions))
# Out:
# 1.0

# %%
from sklearn import tree
classifier2=tree.DecisionTreeClassifier()

# %%
classifier2.fit(x_train,y_train)
predictions=classifier2.predict(x_test)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,predictions))
# Out:
# 0.9666666666666667
